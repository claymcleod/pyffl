# %% [markdown]
# # Seattle Seahawks Analysis
#
# This is meant to be a proof of concept analysis of the Seattle Seahawks and Russel Wilson. Using pyffl, I will load all of the Seahawk's games since 2013 and plot their score vs their opponents scores.

# %%
# Loading default settings

# %matplotlib inline
import numpy as np
import pandas
import matplotlib.pyplot as plt
import seaborn as sns

df = pandas.read_csv('../data/players.csv')
df["score_diff"] = df["own_score"] - df["opp_score"]
df["is_home"] = df.apply(lambda row: 1 if row["home"] ==  row["team"] else 0, axis=1)

# %% [markdown]
# The graph below represents all games since 2013. The X axis represents the Seahawk's score and the Y axis represents their opponent's score. Comparing the seahawks to other teams in the NFL, I found that their scores were highly variable. Interestingly enough, that the densest porition of the graph hovers around the 10-20 point mark.

# %%
team = df[df["team"] == "SEA"]
ax = sns.kdeplot(team["own_score"], team["opp_score"],
                 cmap="Reds", shade=True, shade_lowest=False)

# %%
seattle_home = team[team["is_home"] == 1]
seattle_away = team[team["is_home"] == 0]

chart1, ax1 = plt.subplots()
t = np.arange(max(seattle_home["own_score"]))
s = t

plt.plot(t, s)
ax1.set_title("Seahawks at Home")
ax1.text(7, 32, r'Loss', fontsize=14)
ax1.text(40, 0, r'Win', fontsize=14)

sns.kdeplot(seattle_home["own_score"], seattle_home["opp_score"],
                 cmap="Reds", shade=True, shade_lowest=False, ax=ax1)


chart2, ax2 = plt.subplots()
t = np.arange(max(seattle_away["own_score"]) + 10)
s = t

plt.plot(t, s)

ax2.set_title("Seahawks at Away")
ax2.text(7, 32, r'Loss', fontsize=14)
ax2.text(40, 0, r'Win', fontsize=14)
sns.kdeplot(seattle_away["own_score"], seattle_away["opp_score"],
                 cmap="Blues", shade=True, shade_lowest=False, ax=ax2)

# %%
df[(df["name"] == "R.Wilson") & (df["team"] == "SEA")]
# Out:
#        week  year home away position team  own_score  opp_score      name  \
# 131       1  2013  CAR  SEA       QB  SEA         12          7  R.Wilson
# 1573      2  2013  SEA   SF       QB  SEA         29          3  R.Wilson
# 2374      3  2013  SEA  JAC       QB  SEA         45         17  R.Wilson
# 2777      4  2013  HOU  SEA       QB  SEA         23         20  R.Wilson
# 3596      5  2013  IND  SEA       QB  SEA         28         34  R.Wilson
# 4651      6  2013  SEA  TEN       QB  SEA         20         13  R.Wilson
# 4957      7  2013  ARI  SEA       QB  SEA         34         22  R.Wilson
# 6436      8  2013  STL  SEA       QB  SEA         14          9  R.Wilson
# 6903      9  2013  SEA   TB       QB  SEA         27         24  R.Wilson
# 7252     10  2013  ATL  SEA       QB  SEA         33         10  R.Wilson
# 8579     11  2013  SEA  MIN       QB  SEA         41         20  R.Wilson
# 10311    13  2013  SEA   NO       QB  SEA         34          7  R.Wilson
# 11098    14  2013   SF  SEA       QB  SEA         17         19  R.Wilson
# 11640    15  2013  NYG  SEA       QB  SEA         23          0  R.Wilson
# 12701    16  2013  SEA  ARI       QB  SEA         10         17  R.Wilson
# 13774    17  2013  SEA  STL       QB  SEA         27          9  R.Wilson
# 13827     1  2014  SEA   GB       QB  SEA         36         16  R.Wilson
# 15216     2  2014   SD  SEA       QB  SEA         21         30  R.Wilson
# 16303     3  2014  SEA  DEN       QB  SEA         26         20  R.Wilson
# 17987     5  2014  WAS  SEA       QB  SEA         27         17  R.Wilson
# 18664     6  2014  SEA  DAL       QB  SEA         23         30  R.Wilson
# 19305     7  2014  STL  SEA       QB  SEA         26         28  R.Wilson
# 19804     8  2014  CAR  SEA       QB  SEA         13          9  R.Wilson
# 21048     9  2014  SEA  OAK       QB  SEA         30         24  R.Wilson
# 21788    10  2014  SEA  NYG       QB  SEA         38         17  R.Wilson
# 22273    11  2014   KC  SEA       QB  SEA         20         24  R.Wilson
# 23289    12  2014  SEA  ARI       QB  SEA         19          3  R.Wilson
# 23692    13  2014   SF  SEA       QB  SEA         19          3  R.Wilson
# 25156    14  2014  PHI  SEA       QB  SEA         24         14  R.Wilson
# 26013    15  2014  SEA   SF       QB  SEA         17          7  R.Wilson
# 26971    16  2014  ARI  SEA       QB  SEA         35          6  R.Wilson
# 27893    17  2014  SEA  STL       QB  SEA         20          6  R.Wilson
# 28082     1  2015  STL  SEA       QB  SEA         31         34  R.Wilson
# 29611     2  2015   GB  SEA       QB  SEA         17         27  R.Wilson
# 30347     3  2015  SEA  CHI       QB  SEA         26          0  R.Wilson
#
#        own_team_first_downs     ...      defense_tkl  rushing_lng  \
# 131                      18     ...              NaN            7
# 1573                     19     ...              NaN           11
# 2374                     28     ...              NaN           10
# 2777                     15     ...              NaN           25
# 3596                     21     ...              NaN           22
# 4651                     24     ...              NaN           23
# 4957                     21     ...              NaN           11
# 6436                      7     ...              NaN           17
# 6903                     26     ...              NaN           16
# 7252                     25     ...              NaN           10
# 8579                     16     ...              NaN           12
# 10311                    23     ...              NaN           15
# 11098                    13     ...              NaN            2
# 11640                    21     ...              NaN           16
# 12701                    10     ...              NaN           27
# 13774                    20     ...              NaN            8
# 13827                    25     ...              NaN           13
# 15216                    14     ...              NaN           13
# 16303                    26     ...              NaN            9
# 17987                    20     ...              NaN           29
# 18664                     9     ...              NaN            9
# 19305                    25     ...              NaN           52
# 19804                    19     ...              NaN           15
# 21048                    21     ...              NaN           19
# 21788                    27     ...              NaN           26
# 22273                    25     ...              NaN           14
# 23289                    16     ...              NaN           40
# 23692                    16     ...              NaN           12
# 25156                    28     ...              NaN           26
# 26013                    18     ...              NaN           19
# 26971                    23     ...              NaN           55
# 27893                    16     ...              NaN            6
# 28082                    21     ...              NaN           10
# 29611                    21     ...              NaN           17
# 30347                    17     ...              NaN           13
#
#        opp_team_punt_cnt  punting_lng  passing_tds  kicking_fgm  \
# 131                    5          NaN            1          NaN
# 1573                   4          NaN            1          NaN
# 2374                   7          NaN            4          NaN
# 2777                   7          NaN            0          NaN
# 3596                   3          NaN            2          NaN
# 4651                   4          NaN            0          NaN
# 4957                   4          NaN            3          NaN
# 6436                   4          NaN            2          NaN
# 6903                   6          NaN            2          NaN
# 7252                   5          NaN            2          NaN
# 8579                   3          NaN            2          NaN
# 10311                  6          NaN            3          NaN
# 11098                  4          NaN            1          NaN
# 11640                  8          NaN            1          NaN
# 12701                  5          NaN            1          NaN
# 13774                  7          NaN            1          NaN
# 13827                  4          NaN            2          NaN
# 15216                  3          NaN            2          NaN
# 16303                  8          NaN            2          NaN
# 17987                  8          NaN            2          NaN
# 18664                  3          NaN            0          NaN
# 19305                  3          NaN            2          NaN
# 19804                  2          NaN            1          NaN
# 21048                  6          NaN            0          NaN
# 21788                  5          NaN            0          NaN
# 22273                  2          NaN            2          NaN
# 23289                  7          NaN            1          NaN
# 23692                  5          NaN            1          NaN
# 25156                  8          NaN            2          NaN
# 26013                  5          NaN            1          NaN
# 26971                  9          NaN            2          NaN
# 27893                  5          NaN            0          NaN
# 28082                  3          NaN            1          NaN
# 29611                  3          NaN            2          NaN
# 30347                 10          NaN            1          NaN
#
#        opp_team_turnovers  punting_avg  defense_ast  score_diff
# 131                     2          NaN          NaN           5
# 1573                    5          NaN          NaN          26
# 2374                    3          NaN          NaN          28
# 2777                    3          NaN          NaN           3
# 3596                    2          NaN          NaN          -6
# 4651                    2          NaN          NaN           7
# 4957                    2          NaN          NaN          12
# 6436                    2          NaN          NaN           5
# 6903                    0          NaN          NaN           3
# 7252                    1          NaN          NaN          23
# 8579                    4          NaN          NaN          21
# 10311                   1          NaN          NaN          27
# 11098                   1          NaN          NaN          -2
# 11640                   5          NaN          NaN          23
# 12701                   4          NaN          NaN          -7
# 13774                   2          NaN          NaN          18
# 13827                   1          NaN          NaN          20
# 15216                   0          NaN          NaN          -9
# 16303                   2          NaN          NaN           6
# 17987                   0          NaN          NaN          10
# 18664                   2          NaN          NaN          -7
# 19305                   0          NaN          NaN          -2
# 19804                   2          NaN          NaN           4
# 21048                   3          NaN          NaN           6
# 21788                   2          NaN          NaN          21
# 22273                   2          NaN          NaN          -4
# 23289                   1          NaN          NaN          16
# 23692                   3          NaN          NaN          16
# 25156                   2          NaN          NaN          10
# 26013                   0          NaN          NaN          10
# 26971                   1          NaN          NaN          29
# 27893                   3          NaN          NaN          14
# 28082                   3          NaN          NaN          -3
# 29611                   1          NaN          NaN         -10
# 30347                   0          NaN          NaN          26
#
# [35 rows x 87 columns]

# %%
russel_wilson = df[(df["name"] == "R.Wilson") & (df["team"] == "SEA")]
sns.set(color_codes=True)
rw_stats = russel_wilson[["passing_yds", "passing_tds", "passing_att","rushing_yds", "rushing_att", "own_team_first_downs", "score_diff", "is_home"]].fillna(0)

rw_stats_corr = rw_stats.corr()

g = sns.heatmap(rw_stats_corr, annot=True)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
